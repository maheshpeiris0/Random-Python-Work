# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
df=pd.read_parquet('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/polygon-daily-hr-returns_us_stocks_2024-03-20.parquet')

# %%
df.head()
# Out:
#       ticker  todaysChangePerc  todaysChange  day_open  day_high    day_low  \
# 0  VHAI.WS.B        597.336213      82.97000   13.0000   96.8600  13.000000
# 1      SMXWW        316.666667       0.01900    0.0147    0.0240   0.012749
# 2       XTLB        168.269231       1.75000    1.1200    2.7600   1.120000
# 3     WBX.WS        135.020661       0.13070    0.1109    0.2275   0.110000
# 4      AREBW        131.696015       0.01421    0.0109    0.0200   0.010376
#
#    day_close  day_volume    day_vw      min_av  ...    min_c  min_volume  \
# 0    96.8600      2705.0  27.43300      2705.0  ...  96.8600       300.0
# 1     0.0230    237268.0   0.01850    237268.0  ...   0.0250       646.0
# 2     2.3800  14785085.0   2.16940  14785085.0  ...   2.7000     15440.0
# 3     0.2275     37120.0   0.17190     37070.0  ...   0.2275       200.0
# 4     0.0170    142140.0   0.01415    142140.0  ...   0.0250       500.0
#
#     min_vw  prevDay_open  prevDay_high  prevDay_low  prevDay_close  \
# ...

# %%
df_sort=df.sort_values(by='todaysChangePerc',ascending=False)

# %%
df_sort.loc[df_sort['day_open']>1].head(20)
# Out:
#        ticker  todaysChangePerc  todaysChange  day_open  day_high  day_low  \
# 0   VHAI.WS.B        597.336213       82.9700   13.0000   96.8600  13.0000
# 2        XTLB        168.269231        1.7500    1.1200    2.7600   1.1200
# 14       CZOO         68.075117        1.4500    2.3200    3.8115   2.3000
# 19       TRUG         56.521739        0.6500    2.0000    2.2700   1.5600
# 26       LIDR         48.571429        0.5100    1.0500    1.6600   1.0500
# 27        GVH         47.619048        0.5000    1.0500    1.5600   1.0500
# 35       WORX         39.788732        1.1300    3.3600    4.4400   3.1500
# 37        TGL         39.269406        1.7200    7.2800    8.6900   5.5000
# 41       WULF         36.046512        0.6200    1.7100    2.3300   1.7000
# 42       SWVL         36.041225        3.0599    8.7000   11.8584   8.5000
# 45      DWACU         34.268620       14.0501   47.0801   55.0500  47.0801
# ...

# %%
df.query('ticker=="XTLB"')
# Out:
#   ticker  todaysChangePerc  todaysChange  day_open  day_high  day_low  \
# 2   XTLB        168.269231          1.75      1.12      2.76     1.12
#
#    day_close  day_volume  day_vw      min_av  ...  min_c  min_volume  min_vw  \
# 2       2.38  14785085.0  2.1694  14785085.0  ...    2.7     15440.0   2.711
#
#    prevDay_open  prevDay_high  prevDay_low  prevDay_close  prevDay_volume  \
# 2          1.12          1.12          1.0           1.04          7825.0
#
#    prevDay_vw        datetime_est
# 2      1.0251 2024-03-20 17:30:08
#
# [1 rows x 25 columns]

# %%
dataset = pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/XTLB.json', lines=True)

# %%
def diagram_stock(file_path):
    df=pd.read_json(file_path, lines=True)
    df['datetime_est']=pd.to_datetime(df['start_timestamp'],unit='ms',utc=True).dt.tz_convert('US/Eastern')
    fig, ax = plt.subplots()
    ax.plot(df['datetime_est'], df['close'])
    ax.set(xlabel='Date', ylabel='Close Price', title='Stock Price')
    ax.grid()
    plt.show()

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/XTLB.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/TRUG.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/CZOO.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/WORX.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/TGL.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/IREN.json')

# %%
diagram_stock('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/ANVS.json')

# %%
ABVS_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/ANVS.json', lines=True)
TGLO_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/TGL.json', lines=True)
WORX_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/WORX.json', lines=True)
CZOO_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/CZOO.json', lines=True)
TRUG_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/TRUG.json', lines=True)
XTLB_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/XTLB.json', lines=True)
TGL_DF=pd.read_json('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/TGL.json', lines=True)

# %%
frames = [ABVS_DF, TGLO_DF, WORX_DF, CZOO_DF, TRUG_DF, XTLB_DF, TGL_DF]

result_df = pd.concat(frames,ignore_index=True)

# %%
result_df.shape
# Out:
# (50224, 15)

# %%
result_df.head()
# Out:
#   event_type symbol  volume  accumulated_volume  official_open_price     vwap  \
# 0          A   ANVS     200               15039                  NaN   9.8600
# 1          A   ANVS     100               15267                  NaN   9.9500
# 2          A   ANVS    1490               16807                  NaN  10.0000
# 3          A   ANVS     515               17342                  NaN  10.0084
# 4          A   ANVS     750               18122                  NaN  10.0089
#
#       open    close     high      low  aggregate_vwap  average_size  \
# 0   9.8600   9.8600   9.8600   9.8600         10.0747           200
# 1   9.9500   9.9500   9.9500   9.9500         10.0731           100
# 2  10.0000  10.0000  10.0000   9.9999         10.0664           298
# 3  10.0084  10.0084  10.0084  10.0084         10.0647           515
# 4  10.0100  10.0100  10.0100  10.0100         10.0622           187
#
#    start_timestamp  end_timestamp  otc
# 0    1710939482000  1710939483000  NaN
# ...

# %%
result_df.to_parquet('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/stocks_gain_test.parquet')

# %%
my_df=pd.read_parquet('/workspaces/Random-Python-Work/2024/March/RandomValuesGenerations/stocks_gain_test.parquet')

# %%
my_df['symbol'].value_counts()
# Out:
# symbol
# TGL     16728
# TRUG    12225
# WORX     8824
# XTLB     7817
# ANVS     2432
# CZOO     2198
# Name: count, dtype: int64

# %%
dataset.shape
# Out:
# (7817, 15)

# %%
def random_value(df):
    df.sort_values(by='start_timestamp',ascending=True,inplace=True)
    for i in range(df.shape[0]):
        print(dict(df.iloc[i]))
        time.sleep(0.2)

# %%
random_value(my_df)
# Out:
# {'event_type': 'A', 'symbol': 'TGL', 'volume': 663, 'accumulated_volume': 7826656, 'official_open_price': nan, 'vwap': 7.467, 'open': 7.47, 'close': 7.45, 'high': 7.47, 'low': 7.45, 'aggregate_vwap': 6.8906, 'average_size': 25, 'start_timestamp': 1710939192000, 'end_timestamp': 1710939193000, 'otc': nan}
# {'event_type': 'A', 'symbol': 'TGL', 'volume': 663, 'accumulated_volume': 7826656, 'official_open_price': nan, 'vwap': 7.467, 'open': 7.47, 'close': 7.45, 'high': 7.47, 'low': 7.45, 'aggregate_vwap': 6.8906, 'average_size': 25, 'start_timestamp': 1710939192000, 'end_timestamp': 1710939193000, 'otc': nan}
# {'event_type': 'A', 'symbol': 'TGL', 'volume': 663, 'accumulated_volume': 7826656, 'official_open_price': nan, 'vwap': 7.467, 'open': 7.47, 'close': 7.45, 'high': 7.47, 'low': 7.45, 'aggregate_vwap': 6.8906, 'average_size': 25, 'start_timestamp': 1710939192000, 'end_timestamp': 1710939193000, 'otc': nan}
# ...
